# %% [markdown]
# # House Prices: Advanced Regression Techniques
# In this kaggle comepetition, one has to predict the final price of each home given its features. In this comepetition, most of the datatype of features are `string` instead of `float`.  <br/>
# More detail can be found [here](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <center>$1^{st}.$ Download data form kaggle </center>

# %%
import sys, os,glob
import zipfile

def unzip():
    if os.path.isfile('train.csv') and os.path.isfile('test.csv'):  # in general, train / test on kaggle has the same name
        print('files have been unzipped.')
    else:
        unzip_list = glob.glob('*zip')
        for zipFile in unzip_list:
            with zipfile.ZipFile(zipFile,"r") as zip_ref:
                zip_ref.extractall('./')
unzip()
# Out:
# files have been unzipped.

# %% [markdown]
# ### <center>$2^{nd}.$ feature extraction and visulization </center>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

trainDF = pd.read_csv('train.csv')
testDF  = pd.read_csv('test.csv')
# print(trainDF.info())
# print(trainDF.dtypes)
print(set(trainDF.dtypes))
# print(set(trainDF.columns)- set(testDF.columns))
# Out:
# {dtype('O'), dtype('int64'), dtype('float64')}

# %% [markdown]
# Here we try to saperate the data into 2 parts. One  composed of `nums`, and the other one are `strings`. <br>
# For `nums` data, we want to perform some data cleaning techniques such as :
# * reducing the outlier
# * standarlizing data
# * filling in NA curwolumns

# %%
# saparate data 
trainDF_nums = trainDF[[c for c in trainDF.columns if trainDF.dtypes[c] in {np.dtype("float64"),np.dtype("int64")} ]]
print(trainDF_nums.shape)  # 38 features
trainDF_strings = trainDF[[c for c in trainDF.columns if trainDF.dtypes[c] in {np.dtype("object")}]]
print(trainDF_strings.shape)  # 43 features
print(trainDF.shape)  # 81 features = 38 + 43
print(trainDF_nums.head())
print(trainDF_strings.head())
# Out:
# (1460, 38)
# (1460, 43)
# (1460, 81)
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0            0         0        0       2    2008
# 1              0          0            0         0        0       5    2007
# 2              0          0            0         0        0       9    2008
# 3            272          0            0         0        0       2    2006
# 4              0          0            0         0        0      12    2008
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
#
# [5 rows x 38 columns]
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
#   PavedDrive PoolQC Fence MiscFeature SaleType SaleCondition
# 0          Y    NaN   NaN         NaN       WD        Normal
# 1          Y    NaN   NaN         NaN       WD        Normal
# 2          Y    NaN   NaN         NaN       WD        Normal
# 3          Y    NaN   NaN         NaN       WD       Abnorml
# 4          Y    NaN   NaN         NaN       WD        Normal
#
# [5 rows x 43 columns]

# %%
# to see the outlier
# (1) use box plot: those dots are outliers / one can use scatter plot to see outlier
trainDF_nums = trainDF[[c for c in trainDF.columns if trainDF.dtypes[c] in {np.dtype("float64"),np.dtype("int64")} ]]
sns.boxplot(trainDF_nums["WoodDeckSF"])

#(2) use Z score 
from scipy import stats
z_values = np.abs(stats.zscore(trainDF_nums))
print(z_values)
threshold = 3
trainDF_nums = trainDF_nums[trainDF_nums.where(np.abs(z_values)< threshold)]  # once we get outlier, that's drop it first
print(trainDF_nums.shape)
# print(trainDF_nums.tail())
# Out:
# [[1.73086488 0.07337496        nan ... 1.5991111  0.13877749 0.34727322]
#  [1.7284922  0.87256276        nan ... 0.48911005 0.61443862 0.00728832]
#  [1.72611953 0.07337496        nan ... 0.99089135 0.13877749 0.53615372]
#  ...
#  [1.72611953 0.30985939        nan ... 0.48911005 1.64520971 1.07761115]
#  [1.7284922  0.87256276        nan ... 0.8591104  1.64520971 0.48852299]
#  [1.73086488 0.87256276        nan ... 0.1191097  0.13877749 0.42084081]]
# (1460, 38)
# C:\Miniconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in less
#   # This is added back by InteractiveShellApp.init_path()

# %%
#
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
print(np.NAN < 3)
# Out:
# False
